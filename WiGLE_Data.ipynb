# %%
import sqlite3

PATH="data/WiGLE_Backup.db"
net = "network"
loc = "location"

# %% [markdown]
# # This section we clean the database, only maintain WiFi and Bluetooth data

# %%
con = sqlite3.connect(PATH)
cur=con.cursor()

# %%
query = "DELETE FROM {} WHERE type != ? and type != ?".format(net)
cur.execute(query, ('W', 'B'))

query = "select count(*) from {}".format(net)
print("The number of WiFi and Bluethooth data is",cur.execute(query).fetchone()[0])

con.commit()
con.close()
# Out:
# The number of WiFi and Bluethooth data is 1466

# %% [markdown]
# # This part use some API to encrich the database

# %%
from maclookup import ApiClient
import json
import os

API_KEY = "at_oZ9pLFT3m66EVSyi8XPYM6rMxWYnI"
MACADDR_JSON_FILE = "data/macaddr_json"

# %%
# extract all mac

con = sqlite3.connect(PATH)
cur=con.cursor()

query = "select bssid from {}".format(net)
cur.execute(query)

# %%
rts=cur.fetchall()
rt_str=[]
for rt in rts:
    # transfer all the rt(tuple) into string
    print(rt)
    s = ','.join(rt)
    rt_str.append(s)
    print('After transfer:',s)
con.close()
# Out:
# ('00:01:95:4e:21:63',)
# After transfer: 00:01:95:4e:21:63
# ('00:01:c8:d8:6c:ab',)
# After transfer: 00:01:c8:d8:6c:ab
# ('00:10:07:13:07:31',)
# After transfer: 00:10:07:13:07:31
# ('00:1e:c0:31:62:ee',)
# After transfer: 00:1e:c0:31:62:ee
# ('00:1e:c0:31:65:2b',)
# After transfer: 00:1e:c0:31:65:2b
# ('00:23:05:00:0f:22',)
# After transfer: 00:23:05:00:0f:22
# ('00:2a:10:20:c5:e0',)
# After transfer: 00:2a:10:20:c5:e0
# ('00:2a:10:20:c5:e2',)
# After transfer: 00:2a:10:20:c5:e2
# ('00:2a:10:20:c5:e3',)
# After transfer: 00:2a:10:20:c5:e3
# ('00:2a:10:20:c9:f0',)
# After transfer: 00:2a:10:20:c9:f0
# ('00:2a:10:20:c9:f1',)
# After transfer: 00:2a:10:20:c9:f1
# ('00:2a:10:20:c9:f2',)
# After transfer: 00:2a:10:20:c9:f2
# ('00:2a:10:20:c9:f3',)
# After transfer: 00:2a:10:20:c9:f3
# ('00:2a:10:20:c9:f4',)
# After transfer: 00:2a:10:20:c9:f4
# ('00:2a:10:20:c9:fb',)
# After transfer: 00:2a:10:20:c9:fb
# ('00:2a:10:20:c9:fc',)
# After transfer: 00:2a:10:20:c9:fc
# ...

# %%
json_raw_data={}
yesterday_invoke_finished_at = 0
today_invoke_times = 90
#client = ApiClient(API_KEY)
def extract_by_macaddress():
    client = ApiClient(API_KEY)
    for i in range(yesterday_invoke_finished_at,today_invoke_times):
        #print(client.get_raw_data(rt_str[0], 'json'))
        json_raw_data[rt_str[i]]=json.loads(client.get_raw_data(rt_str[i], 'json').decode())
    
    #print(client.get_vendor('44:38:39:ff:ef:57'))
    #print(client.get('44:38:39:ff:ef:57')) # This one need to use the follwing code to get data
    #response = client.get('44:38:39:ff:ef:57')
    #print(response.vendor_details.is_private)
    #print(response.block_details.date_created)
    
extract_by_macaddress()

# %%
json_raw_data={}
json_raw_data['n']=json.loads(c.decode())
json_raw_data[rt_str[0]]=json.loads(c.decode())
print(json_raw_data)
# Out:
# {'vendorDetails': {'oui': '000195', 'isPrivate': False, 'companyName': 'Sena Tech, Inc', 'companyAddress': '116-23 Shinlim-dong KOREA KR', 'countryCode': 'KR'}, 'blockDetails': {'blockFound': True, 'borderLeft': '000195000000', 'borderRight': '000195FFFFFF', 'blockSize': 16777216, 'assignmentBlockSize': 'MA-L', 'dateCreated': '2000-11-09', 'dateUpdated': '2015-09-27'}, 'macAddressDetails': {'searchTerm': '00:01:95:4e:21:63', 'isValid': True, 'virtualMachine': 'Microsoft Virtual PC / Virtual Server', 'applications': [], 'transmissionType': 'unicast', 'administrationType': 'UAA', 'wiresharkNotes': 'No details', 'comment': ''}}
# ...

# %%
if ~os.path.isfile(MACADDR_JSON_FILE):
    with open(MACADDR_JSON_FILE,'w') as outfile:
        json.dump(json_raw_data, outfile)

# %%
len(json_raw_data)
# Out:
# 90

# %% [markdown]
# # log

# %%
import logging
import datetime

# Get the current date and time
now = datetime.datetime.now()

# Configure the logging module
logging.basicConfig(filename='Log_WiGLE', level=logging.DEBUG)

# Generate a log message
logging.info(now,':Inital successfully, with {} data'.format(len(json_raw_data)))
