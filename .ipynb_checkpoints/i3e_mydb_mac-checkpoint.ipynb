# %%
"""
Extract all the company name of the mac we collected
"""
import sqlite3

# %%
PATH="data/WiGLE_Backup.db"

I3E="i3e"
NET = "network"
VEN = "vendor"

con = sqlite3.connect(PATH)
cur=con.cursor()

# %%
query = "select bssid from {}".format(NET)
cur.execute(query)

sql="SELECT network.bssid,i3e.* FROM i3e, network where i3e.Assignment COLLATE NOCASE = SUBSTR(network.bssid, 1, 8)"

cur.execute(sql)

data = cur.fetchall()
print(len(data))
print(data)

#cur.execute("DELETE FROM vendor")
for row in data:
    cur.execute('INSERT OR IGNORE INTO vendor (mac,Registry,Assignment,OrganizationName,OrganizationAddress) VALUES (?,?,?,?,?)', row)
con.commit()
# Out:
# 450
# [('00:01:95:4e:21:63', 'macL', '00:01:95', 'Sena Technologies, Inc.\n', '116-23 Shinlim-dong\nKOREA\nKR\n'), ('00:01:c8:d8:6c:ab', 'macL', '00:01:C8', 'THOMAS CONRAD CORP.\n', '1908-R KRAMER LANE\nAUSTIN  TX  78758\nUS\n'), ('00:10:07:13:07:31', 'macL', '00:10:07', 'Cisco Systems, Inc\n', '170 W. TASMAN DR.\nSAN JOSE  CA  95134-1706\nUS\n'), ('00:1e:c0:31:62:ee', 'macL', '00:1E:C0', 'Microchip Technology Inc.\n', '2355 W. Chandler Blvd.\nChandler  AZ  85224\nUS\n'), ('00:1e:c0:31:65:2b', 'macL', '00:1E:C0', 'Microchip Technology Inc.\n', '2355 W. Chandler Blvd.\nChandler  AZ  85224\nUS\n'), ('00:23:05:00:0f:22', 'macL', '00:23:05', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c5:e0', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c5:e2', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c5:e3', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c9:f0', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c9:f1', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c9:f2', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c9:f3', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c9:f4', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c9:fb', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c9:fc', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c9:fd', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c9:fe', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:c9:ff', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:d5:cc', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:20:d7:6c', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4a:30', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4a:31', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4a:32', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4a:33', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4a:34', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4a:3b', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4a:3c', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4a:3d', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4a:3e', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4a:3f', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4c:6b', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4c:6d', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  CA  94568\nUS\n'), ('00:2a:10:bf:4c:6e', 'macL', '00:2A:10', 'Cisco Systems, Inc\n', '80 West Tasman Drive\nSan Jose  ...
